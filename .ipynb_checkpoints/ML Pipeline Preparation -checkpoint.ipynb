# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# download nltk library
import nltk
nltk.download(['punkt', 'wordnet','stopwords'])
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# import libraries
import pandas as pd
import re
import pickle
from sqlalchemy import create_engine
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.multioutput import MultiOutputClassifier
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier

# %%
## load data from database
engine = create_engine('sqlite:///disaster_response.db')
df = pd.read_sql("SELECT * FROM messages_categories", engine)
X = df['message']
Y = df.iloc[:,4:40]

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):

    # normalize case,remove punctuation 
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())
    
    # tokenize text
    tokens = word_tokenize(text)
    
    # lemmatize and remove stop words
    lemmatizer  = WordNetLemmatizer()
    stop_words = stopwords.words("english")    
    clean_words = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]        

    return clean_words

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(RandomForestClassifier()))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# perform train test split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30)

# train pipeline

pipeline.fit(X_train,Y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('vect', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip...oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#            n_jobs=1))])

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
# predict on test data
y_pred = pipeline.predict(X_test)  

# print classification report

col_list = list(Y.columns.values)
for i, val in enumerate(col_list):
    print("Random Forest Classification Report for '{}' \n".format(val))
    print(classification_report(Y_test.iloc[:,i], y_pred[:,i]))
# Out:
# Classification Report for 'related'
#
#              precision    recall  f1-score   support
#
#           0       0.63      0.46      0.53      1841
#           1       0.84      0.91      0.88      5964
#           2       0.35      0.40      0.37        60
#
# avg / total       0.79      0.80      0.79      7865
#
# Classification Report for 'request'
#
#              precision    recall  f1-score   support
#
#           0       0.90      0.97      0.94      6556
#           1       0.78      0.46      0.58      1309
#
# avg / total       0.88      0.89      0.88      7865
#
# Classification Report for 'offer'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7833
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      1.00      0.99      7865
#
# Classification Report for 'aid_related'
#
#              precision    recall  f1-score   support
#
#           0       0.75      0.84      0.80      4651
#           1       0.73      0.60      0.66      3214
#
# avg / total       0.74      0.74      0.74      7865
#
# Classification Report for 'medical_help'
#
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      7236
#           1       0.63      0.15      0.24       629
#
# avg / total       0.91      0.92      0.90      7865
#
# Classification Report for 'medical_products'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      7466
#           1       0.69      0.11      0.18       399
#
# avg / total       0.94      0.95      0.94      7865
#
# Classification Report for 'search_and_rescue'
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      7649
#           1       0.61      0.05      0.09       216
#
# avg / total       0.96      0.97      0.96      7865
#
# Classification Report for 'security'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7729
#           1       0.00      0.00      0.00       136
#
# avg / total       0.97      0.98      0.97      7865
#
# Classification Report for 'military'
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      7617
#           1       0.45      0.04      0.07       248
#
# avg / total       0.95      0.97      0.96      7865
#
# Classification Report for 'child_alone'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7865
#
# avg / total       1.00      1.00      1.00      7865
#
# Classification Report for 'water'
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      7381
#           1       0.84      0.31      0.46       484
#
# avg / total       0.95      0.95      0.94      7865
#
# Classification Report for 'food'
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.97      7008
#           1       0.84      0.52      0.64       857
#
# avg / total       0.93      0.94      0.93      7865
#
# Classification Report for 'shelter'
#
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      7174
#           1       0.81      0.29      0.43       691
#
# avg / total       0.93      0.93      0.92      7865
#
# Classification Report for 'clothing'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7725
#           1       0.62      0.06      0.10       140
#
# avg / total       0.98      0.98      0.98      7865
#
# Classification Report for 'money'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7706
#           1       0.83      0.03      0.06       159
#
# avg / total       0.98      0.98      0.97      7865
#
# Classification Report for 'missing_people'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7774
#           1       0.75      0.03      0.06        91
#
# avg / total       0.99      0.99      0.98      7865
#
# Classification Report for 'refugees'
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      7609
#           1       0.70      0.09      0.16       256
#
# avg / total       0.96      0.97      0.96      7865
#
# Classification Report for 'death'
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      7509
#           1       0.76      0.19      0.31       356
#
# avg / total       0.95      0.96      0.95      7865
#
# Classification Report for 'other_aid'
#
#              precision    recall  f1-score   support
#
#           0       0.88      0.99      0.93      6846
#           1       0.48      0.05      0.09      1019
#
# avg / total       0.82      0.87      0.82      7865
#
# Classification Report for 'infrastructure_related'
#
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.97      7348
#           1       0.38      0.01      0.02       517
#
# avg / total       0.90      0.93      0.90      7865
#
# Classification Report for 'transport'
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      7485
#           1       0.74      0.15      0.25       380
#
# avg / total       0.95      0.96      0.94      7865
#
# Classification Report for 'buildings'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      7467
#           1       0.67      0.09      0.16       398
#
# avg / total       0.94      0.95      0.93      7865
#
# Classification Report for 'electricity'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7699
#           1       0.29      0.01      0.02       166
#
# avg / total       0.96      0.98      0.97      7865
#
# Classification Report for 'tools'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7827
#           1       0.00      0.00      0.00        38
#
# avg / total       0.99      1.00      0.99      7865
#
# Classification Report for 'hospitals'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7778
#           1       0.00      0.00      0.00        87
#
# avg / total       0.98      0.99      0.98      7865
#
# Classification Report for 'shops'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7838
#           1       0.00      0.00      0.00        27
#
# avg / total       0.99      1.00      0.99      7865
#
# Classification Report for 'aid_centers'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7776
#           1       0.00      0.00      0.00        89
#
# avg / total       0.98      0.99      0.98      7865
#
# Classification Report for 'other_infrastructure'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      7504
#           1       0.17      0.00      0.01       361
#
# avg / total       0.92      0.95      0.93      7865
#
# Classification Report for 'weather_related'
#
#              precision    recall  f1-score   support
#
#           0       0.86      0.95      0.91      5677
#           1       0.84      0.61      0.70      2188
#
# avg / total       0.86      0.86      0.85      7865
#
# Classification Report for 'floods'
#
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      7193
#           1       0.90      0.30      0.45       672
#
# avg / total       0.94      0.94      0.92      7865
#
# Classification Report for 'storm'
#
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      7132
#           1       0.78      0.45      0.57       733
#
# avg / total       0.93      0.94      0.93      7865
#
# Classification Report for 'fire'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7776
#           1       0.00      0.00      0.00        89
#
# avg / total       0.98      0.99      0.98      7865
#
# Classification Report for 'earthquake'
#
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      7117
#           1       0.89      0.71      0.79       748
#
# avg / total       0.96      0.96      0.96      7865
#
# Classification Report for 'cold'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7722
#           1       0.72      0.09      0.16       143
#
# avg / total       0.98      0.98      0.98      7865
#
# Classification Report for 'other_weather'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      7455
#           1       0.36      0.02      0.04       410
#
# avg / total       0.92      0.95      0.92      7865
#
# Classification Report for 'direct_report'
#
#              precision    recall  f1-score   support
#
#           0       0.86      0.97      0.91      6388
#           1       0.74      0.32      0.45      1477
#
# avg / total       0.84      0.85      0.83      7865
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# pipeline.get_params().keys()

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %% [markdown]
# parameters = {
#         'clf__estimator__n_estimators': [20, 30, 50],
#         'tfidf__use_idf' : (True,False)
#  }
#
# cv = GridSearchCV(pipeline, param_grid=parameters)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %% [markdown]
# # predict on test data
# cv.fit(X_train,Y_train)
# y_pred = cv.predict(X_test)
#
# # print classification report
#
# col_list = list(Y.columns.values)
# for i, val in enumerate(col_list):
#     print("Random Forest Classification Report for '{}' \n".format(val))
#     print(classification_report(Y_test.iloc[:,i], y_pred[:,i]))

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
knn_pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(KNeighborsClassifier()))
])

knn_pipeline.fit(X_train,Y_train)

# predict on test data
knn_y_pred = knn_pipeline.predict(X_test)  

# print classification report

col_list = list(Y.columns.values)
for i, val in enumerate(col_list):
    print("KNeighbors Classification Report for '{}' \n".format(val))
    print(classification_report(Y_test.iloc[:,i], knn_y_pred[:,i]))
# Out:
# KNeighbors Classification Report for 'related'
#
#              precision    recall  f1-score   support
#
#           0       0.68      0.14      0.24      1841
#           1       0.80      0.09      0.16      5964
#           2       0.01      0.90      0.02        60
#
# avg / total       0.77      0.11      0.18      7865
#
# KNeighbors Classification Report for 'request'
#
#              precision    recall  f1-score   support
#
#           0       0.84      1.00      0.91      6556
#           1       0.78      0.08      0.14      1309
#
# avg / total       0.83      0.84      0.79      7865
#
# KNeighbors Classification Report for 'offer'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7833
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      1.00      0.99      7865
#
# KNeighbors Classification Report for 'aid_related'
#
#              precision    recall  f1-score   support
#
#           0       0.60      0.99      0.75      4651
#           1       0.73      0.04      0.07      3214
#
# avg / total       0.65      0.60      0.47      7865
#
# KNeighbors Classification Report for 'medical_help'
#
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      7236
#           1       1.00      0.00      0.00       629
#
# avg / total       0.93      0.92      0.88      7865
#
# KNeighbors Classification Report for 'medical_products'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      7466
#           1       0.57      0.01      0.02       399
#
# avg / total       0.93      0.95      0.93      7865
#
# KNeighbors Classification Report for 'search_and_rescue'
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      7649
#           1       0.00      0.00      0.00       216
#
# avg / total       0.95      0.97      0.96      7865
#
# KNeighbors Classification Report for 'security'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7729
#           1       0.00      0.00      0.00       136
#
# avg / total       0.97      0.98      0.97      7865
#
# KNeighbors Classification Report for 'military'
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      7617
#           1       0.00      0.00      0.00       248
#
# avg / total       0.94      0.97      0.95      7865
#
# KNeighbors Classification Report for 'child_alone'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7865
#
# avg / total       1.00      1.00      1.00      7865
#
# KNeighbors Classification Report for 'water'
#
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      7381
#           1       0.73      0.04      0.07       484
#
# avg / total       0.93      0.94      0.91      7865
#
# KNeighbors Classification Report for 'food'
#
#              precision    recall  f1-score   support
#
#           0       0.90      1.00      0.94      7008
#           1       0.81      0.06      0.11       857
#
# avg / total       0.89      0.90      0.85      7865
#
# KNeighbors Classification Report for 'shelter'
#
#              precision    recall  f1-score   support
#
#           0       0.91      1.00      0.96      7174
#           1       0.83      0.04      0.07       691
#
# avg / total       0.91      0.91      0.88      7865
#
# KNeighbors Classification Report for 'clothing'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7725
#           1       0.75      0.02      0.04       140
#
# avg / total       0.98      0.98      0.97      7865
#
# KNeighbors Classification Report for 'money'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7706
#           1       1.00      0.01      0.02       159
#
# avg / total       0.98      0.98      0.97      7865
#
# KNeighbors Classification Report for 'missing_people'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7774
#           1       0.00      0.00      0.00        91
#
# avg / total       0.98      0.99      0.98      7865
#
# KNeighbors Classification Report for 'refugees'
#
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      7609
#           1       0.00      0.00      0.00       256
#
# avg / total       0.94      0.97      0.95      7865
#
# KNeighbors Classification Report for 'death'
#
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      7509
#           1       1.00      0.02      0.04       356
#
# avg / total       0.96      0.96      0.93      7865
#
# KNeighbors Classification Report for 'other_aid'
#
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      6846
#           1       0.26      0.01      0.01      1019
#
# avg / total       0.79      0.87      0.81      7865
#
# KNeighbors Classification Report for 'infrastructure_related'
#
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.97      7348
#           1       0.67      0.00      0.01       517
#
# avg / total       0.92      0.93      0.90      7865
#
# KNeighbors Classification Report for 'transport'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      7485
#           1       0.00      0.00      0.00       380
#
# avg / total       0.91      0.95      0.93      7865
#
# KNeighbors Classification Report for 'buildings'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      7467
#           1       0.83      0.01      0.02       398
#
# avg / total       0.94      0.95      0.93      7865
#
# KNeighbors Classification Report for 'electricity'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7699
#           1       0.00      0.00      0.00       166
#
# avg / total       0.96      0.98      0.97      7865
#
# KNeighbors Classification Report for 'tools'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7827
#           1       0.00      0.00      0.00        38
#
# avg / total       0.99      1.00      0.99      7865
#
# KNeighbors Classification Report for 'hospitals'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7778
#           1       0.00      0.00      0.00        87
#
# avg / total       0.98      0.99      0.98      7865
#
# KNeighbors Classification Report for 'shops'
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      7838
#           1       0.00      0.00      0.00        27
#
# avg / total       0.99      1.00      0.99      7865
#
# KNeighbors Classification Report for 'aid_centers'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7776
#           1       0.00      0.00      0.00        89
#
# avg / total       0.98      0.99      0.98      7865
#
# KNeighbors Classification Report for 'other_infrastructure'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      7504
#           1       0.00      0.00      0.00       361
#
# avg / total       0.91      0.95      0.93      7865
#
# KNeighbors Classification Report for 'weather_related'
#
#              precision    recall  f1-score   support
#
#           0       0.73      1.00      0.84      5677
#           1       0.83      0.05      0.10      2188
#
# avg / total       0.76      0.73      0.64      7865
#
# KNeighbors Classification Report for 'floods'
#
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      7193
#           1       0.80      0.01      0.01       672
#
# avg / total       0.91      0.91      0.87      7865
#
# KNeighbors Classification Report for 'storm'
#
#              precision    recall  f1-score   support
#
#           0       0.91      1.00      0.95      7132
#           1       0.69      0.01      0.02       733
#
# avg / total       0.89      0.91      0.86      7865
#
# KNeighbors Classification Report for 'fire'
#
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      7776
#           1       0.00      0.00      0.00        89
#
# avg / total       0.98      0.99      0.98      7865
#
# KNeighbors Classification Report for 'earthquake'
#
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.95      7117
#           1       0.82      0.13      0.22       748
#
# avg / total       0.91      0.91      0.89      7865
#
# KNeighbors Classification Report for 'cold'
#
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      7722
#           1       0.50      0.01      0.03       143
#
# avg / total       0.97      0.98      0.97      7865
#
# KNeighbors Classification Report for 'other_weather'
#
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      7455
#           1       0.67      0.00      0.01       410
#
# avg / total       0.93      0.95      0.92      7865
#
# KNeighbors Classification Report for 'direct_report'
#
#              precision    recall  f1-score   support
#
#           0       0.82      1.00      0.90      6388
#           1       0.73      0.05      0.10      1477
#
# avg / total       0.80      0.82      0.75      7865
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
filename = 'classifier.pkl'
pickle.dump(pipeline, open(filename, 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
